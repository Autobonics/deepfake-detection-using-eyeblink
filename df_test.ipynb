# %%
from _ear_utils import get_vid_EAR
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Plot EAR of Original footage

# %%
vid_path='./vid_data/original/1.mp4'
ear_val=get_vid_EAR(vid_path)

# %%
df = pd.DataFrame(data=ear_val, columns=["EAR Value"])
df.plot()
# Out:
# <Axes: >

# %% [markdown]
# Plot EAR of deepfake footage

# %%
vid_path='./vid_data/fake/1.mp4'
ear_val=get_vid_EAR(vid_path)

# %%
df=pd.DataFrame(data=ear_val,columns=["EAR Value"])
df.plot()
# Out:
# <Axes: >
